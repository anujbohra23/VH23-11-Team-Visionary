# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
# %matplotlib inline
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.decomposition import PCA
import random

# %%
df = pd.read_csv(r"C:\Users\Anuj Bohra\Desktop\final_vcet.csv")

# %%
df
# Out:
#      Unnamed: 0 Group             Area exploration        communication  \
# 0             0    No    Data Analysis          No  Enjoy Communicating
# 1             1    No  Computer Vision         Yes  Enjoy Communicating
# 2             2    No              NLP          No  Enjoy Communicating
# 3             3   Yes    Data Analysis         Yes              Neutral
# 4             4   Yes              NLP         Yes  Enjoy Communicating
# ..          ...   ...              ...         ...                  ...
# 745         245    No  Computer Vision         Yes              Dislike
# 746         246   Yes  Computer Vision          No              Neutral
# 747         247    No              NLP         Yes              Neutral
# 748         248   Yes              NLP          No              Neutral
# 749         249   Yes    Deep Learning         Yes              Neutral
#
#     feedback  extracurriculars  help_others  confidence adv_courses  \
# 0     Verbal                 7            1           2          No
# 1     Verbal                 1            1           2          No
# 2     Verbal                 5            2           3          No
# 3    Written                 5            2           1          No
# 4     Verbal                 8            2           2          No
# ..       ...               ...          ...         ...         ...
# 745  Written                 1            7           8         Yes
# 746  Written                 9            8           7         Yes
# 747  Written                 5           10           8         Yes
# 748   Verbal                 3            7          10         Yes
# 749  Written                 4            8           9         Yes
#
#                     Colab  Exp          Resouce  hours     class
# 0             Independent    1  Peer Discussion      2  Beginner
# 1                 Neutral    2         TextBook      1  Beginner
# 2    Highly Collaborating    1  Peer Discussion      2  Beginner
# 3    Highly Collaborating    1      Study Group      2  Beginner
# 4                 Neutral    1         TextBook      2  Beginner
# ..                    ...  ...              ...    ...       ...
# 745               Neutral    7      Study Group      8  Advanced
# 746               Neutral    7  Peer Discussion      7  Advanced
# 747               Neutral   10         TextBook      7  Advanced
# 748  Highly Collaborating    8  Peer Discussion      9  Advanced
# 749               Neutral    8      Study Group      9  Advanced
#
# [750 rows x 15 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x=df.iloc[:,1:12]
y=df.iloc[:,-1]
df.isna().sum()
# Out:
# Unnamed: 0          0
# Group               0
# Area                0
# exploration         0
# communication       0
# feedback            0
# extracurriculars    0
# help_others         0
# confidence          0
# adv_courses         0
# Colab               0
# Exp                 0
# Resouce             0
# hours               0
# class               0
# dtype: int64
